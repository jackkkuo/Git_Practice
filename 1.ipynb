# %%
print("1")
print("3")

# %%
print("3")

# %%
conda install nbdime
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\113142\AppData\Local\anaconda3\envs\Python
#
#   added / updated specs:
#     - nbdime
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anyio-4.6.2                |  py312haa95532_0         254 KB
#     argon2-cffi-bindings-21.2.0|  py312h827c3e9_1          41 KB
#     attrs-24.3.0               |  py312haa95532_0         173 KB
#     bleach-6.2.0               |  py312haa95532_0         358 KB
#     brotli-python-1.0.9        |  py312h5da7b33_9         347 KB
#     cffi-1.17.1                |  py312h827c3e9_1         311 KB
#     charset-normalizer-3.3.2   |     pyhd3eb1b0_0          44 KB
#     gitpython-3.1.43           |  py312haa95532_0         364 KB
# ...
